# %% [markdown]
# # Image Colorization – Visualization

# %% [markdown]
# This notebook presents qualitative results of the trained image colorization model.
#
# The notebook:
# - Loads the trained colorization model
# - Applies it to unseen grayscale images
# - Visualizes grayscale input, colorized output, and original image
# - Saves colorized results to disk
#
# This notebook focuses on **visual evaluation**, which is the primary method
# for assessing image colorization performance.

# %%
import sys
import os

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %% [markdown]
# ## Imports

# %%
import os
import matplotlib.pyplot as plt

from src.infer import infer

# %%
TEST_DIR = "../data/test"
RESULTS_DIR = "../results"

os.makedirs(RESULTS_DIR, exist_ok=True)

test_images = [
    os.path.join(TEST_DIR, f)
    for f in os.listdir(TEST_DIR)
    if f.lower().endswith((".jpg", ".jpeg", ".png"))
]

print(f"Found {len(test_images)} test images")
# Out:
# Found 4 test images

# %% [markdown]
# The following section applies the trained model to unseen test images.
# For each image, the grayscale input, model-predicted colorization,
# and original color image are displayed side by side.

# %%
MODEL_PATH = "../models/colorization_model.h5"

for img_path in test_images:
    print(f"\nProcessing: {os.path.basename(img_path)}")
    infer(img_path, model_path=MODEL_PATH)
# Out:
# Processing: 1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# Saved colorized image to results\1.jpg
#
# Processing: 2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# Saved colorized image to results\2.jpg
#
# Processing: 3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 888ms/step
# Saved colorized image to results\3.jpg
#
# Processing: 4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Saved colorized image to results\4.jpg
